# %%
from dotenv import load_dotenv
_ = load_dotenv()
from crewai import Crew, Process, Agent, Task

# %%
planejador_de_viagem = Agent(
    role="Planejador de Viagem",
    goal="Planejar todos os detalhes de uma viagem, incluindo roteiros e atividades",
    backstory="""
    Você é um especialista em planejamento de viagens, sempre em busca de 
    novas aventuras e experiências. Seu objetivo é garantir os detalhes da viagem
    sejam organizados de maneira eficiente e agradável.
    """,
    verbose=True
)

# %%
orcamentista = Agent(
    role="Orçamentista de viagem",
    goal="Estimar o custo total de uma viagem, considerando transporte, hospedagem, alimentação e atividades",
    backstory="""
    Você é um analista financeiro focado em viagem. Sua missão é garantir que os custos estejam
    dento do orcámento, criando estimativas precisas para cada parte da viagem.
    """
)

# %%
planeja_roteiro = Task(
    description="Crie um roteiro detalhado para uma viagem para a Disney em Orlando, EUA, incluindo as cidades, atividades e transporte",
    agent=planejador_de_viagem,
    expected_output="""
    Um roteiro com a sequência de cidades a serem visitadas, as principais
    atividades e o tipo de transporte utilizado  
    """
)

# %%
estima_orcamento = Task(
    description="""Calcule o orçamento total da viagem, levando em consideração
     as cidades, transporte, hospedagem e atividades
    """,
    agent=orcamentista,
    expected_output="""
    Uma estimativa de orçamento detalhada, com custos aproximados para cada item da viagem  
    """
)

# %%
viagem_crew = Crew(
    agents=[planejador_de_viagem, orcamentista],
    tasks=[planeja_roteiro, estima_orcamento],
    process=Process.sequential
)

# %%
result = viagem_crew.kickoff()
# Out:
# # Agent: Planejador de Viagem
# ## Task: Crie um roteiro detalhado para uma viagem incluindo as cidades, atividades e transporte
#
#
# # Agent: Planejador de Viagem
# ## Final Answer:
# **Roteiro Detalhado para uma Viagem pelo Sudeste Asiático: 10 dias**
#
# **Dia 1: Chegada a Bangkok, Tailândia**
# - **Transporte:** Vôo Internacional para o Aeroporto Suvarnabhumi (BKK).
# - **Atividades:**
#   - Check-in no hotel.
#   - Visita ao Grande Palácio e ao Templo do Buda Esmeralda (Wat Phra Kaew).
#   - Jantar em um restaurante local, experimentando pratos tailandeses autênticos.
#
# **Dia 2: Bangkok**
# - **Transporte:** Metrô BTS e taxi aquático.
# - **Atividades:**
#   - Tour de barco pelos canais de Thonburi.
#   - Visita ao Templo do Amanhã (Wat Arun).
#   - Exploração do Mercado Flutuante de Damnoen Saduak (opcional).
#   - Noite no Mercado de Chatuchak (se for fim de semana).
#
# **Dia 3: Ayutthaya**
# - **Transporte:** Trem de Bangkok a Ayutthaya (aproximadamente 1.5 horas).
# - **Atividades:**
#   - Aluguel de bicicleta para explorar as ruínas de Ayutthaya.
#   - Visitas às principais atrações: Wat Mahathat, Wat Phra Si Sanphet e Wat Chaiwatthanaram.
#   - Retorno a Bangkok.
#
# **Dia 4: Voo para Siem Reap, Camboja**
# - **Transporte:** Vôo de Bangkok para Siem Reap (aproximadamente 1 hora).
# - **Atividades:**
#   - Check-in no hotel.
#   - Visita ao Mercado Noturno de Siem Reap para jantar e compras.
#
# **Dia 5: Angkor Wat**
# - **Transporte:** Tuk Tuk.
# - **Atividades:**
#   - Visita às ruínas de Angkor, começando com o famoso templo Angkor Wat ao nascer do sol.
#   - Exploração dos templos de Bayon e Ta Prohm.
#   - Retorno ao hotel e descanso.
#
# **Dia 6: Siem Reap para Phnom Penh**
# - **Transporte:** Ônibus ou minivan (aproximadamente 6 horas).
# - **Atividades:**
#   - Check-in no hotel em Phnom Penh.
#   - Visita ao Museu do Genocídio Tuol Sleng e ao Campo de Extermínio de Choeung Ek.
#   - Jantar em um restaurante à beira do rio Mekong.
#
# **Dia 7: Phnom Penh**
# - **Transporte:** Bicicleta ou tuk tuk.
# - **Atividades:**
#   - Visita ao Palácio Real e à Pagode de Prata.
#   - Exploração do Mercado Central de Phnom Penh para compras de artesanato.
#   - Passeio de barco no rio ao pôr do sol.
#
# **Dia 8: Voo para Hanói, Vietnã**
# - **Transporte:** Vôo de Phnom Penh para Hanói (aproximadamente 1 hora e 15 minutos).
# - **Atividades:**
#   - Check-in no hotel.
#   - Passeio pelo Bairro Antigo e visita ao Lago Hoan Kiem.
#   - Jantar em um restaurante de comida vietnamita.
#
# **Dia 9: Ha Long Bay**
# - **Transporte:** Ônibus de Hanói para Ha Long Bay (aproximadamente 2 horas e 30 minutos).
# - **Atividades:**
#   - Embarque em um cruzeiro de um dia pela Baía de Ha Long.
#   - Visitas a grutas, ilhas e possibilidade de nadar.
#   - Retorno a Hanói.
#
# **Dia 10: Partida de Hanói**
# - **Transporte:** Vôo de saída do Aeroporto Internacional de Nội Bài (HAN) para o destino final.
# - **Atividades:**
#   - Últimas compras de souvenirs na Old Quarter.
#   - Check-out do hotel e traslado para o aeroporto.
#
# Este roteiro abrange uma variedade de experiências culturais e históricas, além de aproveitar o transporte local. É uma excelente maneira de explorar o Sudeste Asiático em 10 dias. Boa viagem!

# %%
print(result.raw)
# Out:
# Abaixo está uma estimativa detalhada do orçamento para a viagem pelas cidades do Sudeste Asiático, considerando transporte, hospedagem, alimentação e atividades ao longo de 10 dias.
#
# **Orçamento Total da Viagem pelo Sudeste Asiático: 10 dias**
#
# 1. **Transporte:**
#    - Vôo Internacional (Brasil a Bangkok): R$ 3.500
#    - Transporte em Bangkok (Metrô BTS e taxi aquático): R$ 40
#    - Trem de Bangkok a Ayutthaya: R$ 20
#    - Vôo de Bangkok a Siem Reap: R$ 500
#    - Tuk Tuk em Siem Reap: R$ 80
#    - Ônibus ou minivan de Siem Reap a Phnom Penh: R$ 80
#    - Bicicleta ou tuk tuk em Phnom Penh: R$ 40
#    - Vôo de Phnom Penh a Hanói: R$ 300
#    - Ônibus de Hanói a Ha Long Bay: R$ 50
#    - Traslado de hotel para o aeroporto em Hanói: R$ 50
#    **Subtotal Transporte: R$ 4.710**
#
# 2. **Hospedagem (10 noites):**
#    - Bangkok (3 noites): R$ 600 (R$ 200/noite)
#    - Siem Reap (3 noites): R$ 600 (R$ 200/noite)
#    - Phnom Penh (2 noites): R$ 400 (R$ 200/noite)
#    - Hanói (2 noites): R$ 400 (R$ 200/noite)
#    **Subtotal Hospedagem: R$ 2.000**
#
# 3. **Alimentação:**
#    - Café da manhã (incluso na hospedagem).
#    - Almoço e jantar em Bangkok (R$ 50/dia por 3 dias): R$ 150
#    - Almoço e jantar em Siem Reap (R$ 50/dia por 3 dias): R$ 150
#    - Almoço e jantar em Phnom Penh (R$ 50/dia por 2 dias): R$ 100
#    - Almoço e jantar em Hanói (R$ 50/dia por 2 dias): R$ 100
#    **Subtotal Alimentação: R$ 500**
#
# 4. **Atividades:**
#    - Grande Palácio e Templo do Buda Esmeralda: R$ 40
#    - Tour de barco pelos canais de Thonburi: R$ 30
#    - Aluguel de bicicleta em Ayutthaya: R$ 20
#    - Ingressos para Angkor Wat: R$ 100
#    - Museu do Genocídio Tuol Sleng e Campo de Extermínio: R$ 20
#    - Palácio Real e Pagode de Prata: R$ 20
#    - Passeio de barco no rio em Phnom Penh: R$ 30
#    - Cruzeiro na Baía de Ha Long: R$ 150
#    **Subtotal Atividades: R$ 410**
#
# **Custo Total da Viagem:**
# - Total Transporte: R$ 4.710
# - Total Hospedagem: R$ 2.000
# - Total Alimentação: R$ 500
# - Total Atividades: R$ 410
#
# **Orçamento Total Estimado: R$ 7.620**
#
# Essa estimativa cobre todos os principais custos da viagem, proporcionando uma visão clara do orçamento necessário para realizar essa incrível jornada pelo Sudeste Asiático. Espero que você tenha uma experiência maravilhosa!
